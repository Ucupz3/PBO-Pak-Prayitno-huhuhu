# %% [markdown]
# #JOBSHEET 01:DASAR BAHASA PEMROGRAMAN PYTHON

# %% [markdown]
# #Praktikum 01. Tipe data dasar

# %%
# 1. Number (int, float, complex)
angka_int = 10
print("angka_int =", angka_int, "->", type(angka_int))

# Float
angka_float = 3.14
print("angka_float =", angka_float, "->", type(angka_float))

# Complex
print("angka_complex =", angka_complex, "->", type(angka_complex))


# 2. Boolean
is_active = True
print("is_active =", is_active, "->", type(is_active))


# 3. String
teks = "Hello, Python!"
print("teks =", teks, "->", type(teks))


# 4. List
daftar_angka = [1, 2, 3, 4, 5]
print("daftar_angka =", daftar_angka, "->", type(daftar_angka))


# 5. Tuple
koordinat = (10, 20)
print("koordinat =", koordinat, "->", type(koordinat))


# 6. Dictionary
data_mahasiswa = {
    "nama": "Andi",
    "nim": "A11.2022.12345",
    "jurusan": "Teknik Informatika"
}
print("data_mahasiswa =", data_mahasiswa, "->", type(data_mahasiswa))


# 7. Set
himpunan_angka = {1, 2, 3, 2, 1}
print("himpunan_angka =", himpunan_angka, "->", type(himpunan_angka))


# 8. Konversi tipe data
nilai_str = "100"
print("\nnilai_str =", nilai_str, "->", type(nilai_str))

nilai_int = int(nilai_str)  # konversi string ke integer
print("nilai_int =", nilai_int, "->", type(nilai_int))
# Out:
# angka_int = 10 -> <class 'int'>
# angka_float = 3.14 -> <class 'float'>
# angka_complex = (2+3j) -> <class 'complex'>
# is_active = True -> <class 'bool'>
# teks = Hello, Python! -> <class 'str'>
# daftar_angka = [1, 2, 3, 4, 5] -> <class 'list'>
# koordinat = (10, 20) -> <class 'tuple'>
# data_mahasiswa = {'nama': 'Andi', 'nim': 'A11.2022.12345', 'jurusan': 'Teknik Informatika'} -> <class 'dict'>
# himpunan_angka = {1, 2, 3} -> <class 'set'>
#
# nilai_str = 100 -> <class 'str'>
# nilai_int = 100 -> <class 'int'>

# %% [markdown]
# #Praktikum 02. Variabel dan Operasi dasar

# %%
# 1. Pendeklarasian Variabel
nama = "Budi"
umur = 20
tinggi = 170.5
is_student = True

print("Nama =", nama)
print("Umur =", umur)
print("Tinggi =", tinggi, "cm")
print("Mahasiswa =", is_student)


# 2. Operasi Aritmetika
a = 10
b = 3

penjumlahan = a + b         # Tambah
pengurangan = a - b         # Kurang
perkalian = a * b           # Kali
pembagian = a / b           # Bagi (hasil float)
pembagian_bulat = a // b    # Bagi (bulat)
modulus = a % b             # Sisa bagi
pangkat = a ** b            # Pemangkatan

print("\nOPERASI ARITMETIKA")
print("a =", a, ", b =", b)
print("Penjumlahan =", penjumlahan)
print("Pengurangan =", pengurangan)
print("Perkalian =", perkalian)
print("Pembagian =", pembagian)
print("Pembagian Bulat =", pembagian_bulat)
print("Modulus =", modulus)
print("Pangkat =", pangkat)


# 3. Operasi Perbandingan (true/false)
lebih_besar = a > b
kurang_dari = a < b
sama_dengan = a == b
tidak_sama = a != b
lebih_besar_sama = a >= b
kurang_sama = a <= b

print("\nOPERASI PERBANDINGAN")
print("a > b =", lebih_besar)
print("a < b =", kurang_dari)
print("a == b =", sama_dengan)
print("a != b =", tidak_sama)
print("a >= b =", lebih_besar_sama)
print("a <= b =", kurang_sama)


# 4. Operasi Logika
# and, or, not
x = True
y = False

logika_and = x and y
logika_or = x or y
logika_not_x = not x

print("\nOPERASI LOGIKA")
print("x =", x, ", y =", y)
print("x and y =", logika_and)
print("x or y =", logika_or)
print("not x =", logika_not_x)


# 5. Percabangan
if a > b and b > 0:
    print("\nKondisi terpenuhi: a lebih besar dari b, dan b masih positif.")
else:
    print("\nKondisi tidak terpenuhi atau b <= 0.")
# Out:
# Nama = Budi
# Umur = 20
# Tinggi = 170.5 cm
# Mahasiswa = True
#
# OPERASI ARITMETIKA
# a = 10 , b = 3
# Penjumlahan = 13
# Pengurangan = 7
# Perkalian = 30
# Pembagian = 3.3333333333333335
# Pembagian Bulat = 3
# Modulus = 1
# Pangkat = 1000
#
# OPERASI PERBANDINGAN
# a > b = True
# a < b = False
# a == b = False
# a != b = True
# a >= b = True
# a <= b = False
#
# OPERASI LOGIKA
# x = True , y = False
# x and y = False
# x or y = True
# not x = False
#
# Kondisi terpenuhi: a lebih besar dari b, dan b masih positif.

# %% [markdown]
# #Praktikum 03. Percabangan

# %%
# 1. IF Sederhana
nilai = 85
print("Contoh IF Sederhana:")
if nilai > 80:
    print("Selamat! Anda lulus dengan nilai tinggi.\n")


# 2. IF-ELSE

umur = 17
print("Contoh IF-ELSE:")
if umur >= 18:
    print("Anda sudah cukup umur untuk mendapatkan SIM.\n")
else:
    print("Anda belum cukup umur untuk mendapatkan SIM.\n")


# 3. IF-ELIF-ELSE

hari = "Rabu"
print("Contoh IF-ELIF-ELSE:")
if hari == "Senin":
    print("Hari Senin. Saatnya kembali bekerja!\n")
elif hari == "Selasa":
    print("Hari Selasa. Jadwal rapat mingguan.\n")
elif hari == "Rabu":
    print("Hari Rabu. Ada diskon di beberapa toko.\n")
else:
    print("Hari lainnya. Atur jadwalmu dengan baik.\n")


# 4. IF Bersarang (Nested IF)

suhu = 35
print("Contoh IF Bersarang (Nested IF):")
if suhu > 30:
    print("Cuaca cukup panas.")
    if suhu > 40:
        print("Bahkan sangat terik! Disarankan banyak minum air.\n")
    else:
        print("Masih relatif normal, tapi tetap jaga kesehatan.\n")
else:
    print("Cuaca sepertinya cukup sejuk.\n")


# 5. Menggabungkan Percabangan dengan Operasi Logika

nilai_teori = 75
nilai_praktik = 80
print("Contoh IF dengan Operasi Logika AND/OR:")
if nilai_teori >= 70 and nilai_praktik >= 70:
    print("Anda lulus karena nilai teori dan praktik memadai.\n")
elif nilai_teori < 70 and nilai_praktik < 70:
    print("Anda perlu meningkatkan nilai teori dan praktik.\n")
elif nilai_teori < 70:
    print("Anda perlu meningkatkan nilai teori.\n")
else:
    print("Anda perlu meningkatkan nilai praktik.\n")


# 6. Penggunaan If Ternary (atau Conditional Expression)

angka = -5
print("Contoh If Ternary (Conditional Expression):")
status = "Positif" if angka > 0 else "Negatif atau Nol"
print("Angka", angka, "=>", status)
# Out:
# Contoh IF Sederhana:
# Selamat! Anda lulus dengan nilai tinggi.
#
# Contoh IF-ELSE:
# Anda belum cukup umur untuk mendapatkan SIM.
#
# Contoh IF-ELIF-ELSE:
# Hari Rabu. Ada diskon di beberapa toko.
#
# Contoh IF Bersarang (Nested IF):
# Cuaca cukup panas.
# Masih relatif normal, tapi tetap jaga kesehatan.
#
# Contoh IF dengan Operasi Logika AND/OR:
# Anda lulus karena nilai teori dan praktik memadai.
#
# Contoh If Ternary (Conditional Expression):
# Angka -5 => Negatif atau Nol

# %% [markdown]
# #Praktikum 04. Perulangan

# %%
# -*- coding: utf-8 -*-

# 1. FOR Loop dengan range()
print("1) FOR loop dengan range()")
for i in range(5):
    print("Perulangan ke-", i)

print()


# 2. FOR Loop untuk mengiterasi List
print("2) FOR loop mengiterasi list")
buah = ["apel", "mangga", "jeruk", "pisang"]
for item in buah:
    print("Buah:", item)

print()


# 3. WHILE Loop
print("3) WHILE loop sederhana")
count = 0
while count < 5:
    print("count =", count)
    count += 1  # increment

print()


# 4. BREAK pada Loop
print("4) BREAK di dalam loop")
for i in range(10):
    if i == 3:
        print("Loop dihentikan pada i =", i)
        break  # mengakhiri loop saat i = 3 [cite: 391]
    print("i =", i)

print()


# 5. CONTINUE pada Loop
print("5) CONTINUE di dalam loop")
for i in range(5):
    if i == 2:
        print("Lewati i =", i, "dengan continue")
        continue  # melewati iterasi saat ini dan lanjut ke iterasi berikutnya [cite: 407]
    print("i =", i)

print()


# 6. NESTED Loop (Loop Bersarang)
print("6) NESTED loop")
for i in range(3):          # Loop luar (outer loop)
    for j in range(2):      # Loop dalam (inner loop)
        print(f"i={i}, j={j}")


print()


# 7. Memanfaatkan ELSE pada Loop
print("7) ELSE pada loop for/while")

for x in range(3):
    print("x =", x)
else:
    print("Loop for telah selesai tanpa break.\n")

y = 0
while y < 3:
    print("y =", y)
    y += 1
else:
    print("Loop while telah selesai tanpa break.\n")


# 8. PASS sebagai placeholder
print("8) PASS (placeholder)")
for i in range(3):
    if i == 1:
        pass  # pass
    print("i =", i)
# Out:
# 1) FOR loop dengan range()
# Perulangan ke- 0
# Perulangan ke- 1
# Perulangan ke- 2
# Perulangan ke- 3
# Perulangan ke- 4
#
# 2) FOR loop mengiterasi list
# Buah: apel
# Buah: mangga
# Buah: jeruk
# Buah: pisang
#
# 3) WHILE loop sederhana
# count = 0
# count = 1
# count = 2
# count = 3
# count = 4
#
# 4) BREAK di dalam loop
# i = 0
# i = 1
# i = 2
# Loop dihentikan pada i = 3
#
# 5) CONTINUE di dalam loop
# i = 0
# i = 1
# Lewati i = 2 dengan continue
# i = 3
# i = 4
#
# 6) NESTED loop
# i=0, j=0
# i=0, j=1
# i=1, j=0
# i=1, j=1
# i=2, j=0
# i=2, j=1
#
# 7) ELSE pada loop for/while
# x = 0
# x = 1
# x = 2
# Loop for telah selesai tanpa break.
#
# y = 0
# y = 1
# y = 2
# Loop while telah selesai tanpa break.
#
# 8) PASS (placeholder)
# i = 0
# i = 1
# i = 2

# %% [markdown]
# #Penugasan Program 1

# %%
print("=== PROGRAM PENGHITUNG BMI (BODY MASS INDEX) ===")

# 1. Mengambil input dari pengguna
berat_kg = float(input("Masukkan berat badan Anda (kg): "))
tinggi_cm = float(input("Masukkan tinggi badan Anda (cm): "))

# 2. Mengonversi tinggi dari cm ke meter
tinggi_m = tinggi_cm / 100

# 3. Menghitung nilai BMI sesuai rumus pada jobsheet
bmi = berat_kg / (tinggi_m ** 2)

# 4. Menentukan kategori BMI menggunakan percabangan (IF-ELIF-ELSE)
if bmi < 18.5:
    kategori = "Underweight (Berat badan kurang)"
elif 18.5 <= bmi <= 24.9:
    kategori = "Normal (Ideal)"
elif 25.0 <= bmi <= 29.9:
    kategori = "Overweight (Berat badan berlebih)"
else:
    kategori = "Obesity (Obesitas)"

# 5. Menampilkan hasil output
print("\n=== HASIL ANALISIS BMI ===")
print(f"Nilai BMI Anda : {bmi:.2f}")
print(f"Kategori       : {kategori}")
# Out:
# === PROGRAM PENGHITUNG BMI (BODY MASS INDEX) ===
# Masukkan berat badan Anda (kg): 55
# Masukkan tinggi badan Anda (cm): 170
#
# === HASIL ANALISIS BMI ===
# Nilai BMI Anda : 19.03
# Kategori       : Normal (Ideal)

# %% [markdown]
# #Penugasan Program 2

# %%
print("=== PROGRAM PENGECEK BILANGAN (GENAP, GANJIL, & PRIMA) ===")

# 1. Mengambil input bilangan bulat dari pengguna
angka = int(input("Masukkan sebuah bilangan bulat positif: "))

# Pastikan angka yang dimasukkan lebih besar dari 0
if angka <= 0:
    print("Silakan masukkan bilangan bulat yang lebih besar dari 0.")
else:
    print("-" * 40)

    # --- BAGIAN 1: MENGECEK GENAP ATAU GANJIL ---
    if angka % 2 == 0:
        status_genap_ganjil = "Genap"
    else:
        status_genap_ganjil = "Ganjil"

    print(f"1. Bilangan {angka} adalah bilangan : {status_genap_ganjil}")


    # --- BAGIAN 2: MENGECEK BILANGAN PRIMA ---


    is_prima = True

    if angka == 1:
        is_prima = False
    else:

        for i in range(2, angka):
            if angka % i == 0:
                is_prima = False
                break

    if is_prima:
        print(f"2. Bilangan {angka} ADALAH Bilangan Prima.")
    else:
        print(f"2. Bilangan {angka} BUKAN Bilangan Prima.")

    print("-" * 40)
# Out:
# === PROGRAM PENGECEK BILANGAN (GENAP, GANJIL, & PRIMA) ===
# Masukkan sebuah bilangan bulat positif: 1
# ----------------------------------------
# 1. Bilangan 1 adalah bilangan : Ganjil
# 2. Bilangan 1 BUKAN Bilangan Prima.
# ----------------------------------------
