# %% [markdown]
# #JOBSHEET 07: PENANGANAN KESALAHAN (EXCEPTION HANDLING)

# %% [markdown]
# #Praktikum 01: try...except Dasar dalam Metode Kelas

# %%
class DataStore:
    def __init__(self, nama_store="Default Store"):

        self._data = {}
        self.nama = nama_store
        print(f"DataStore '{self.nama}' dibuat.")

    def tambah_data(self, key, value):
        print(f"[{self.nama}] Menambahkan data: '{key}' -> {value}")
        self._data[key] = value
        print(" -> Data berhasil ditambahkan.")

    def get_data(self, key):

        print(f"[{self.nama}] Mencoba mengambil data dengan key: '{key}'")
        try:

            nilai = self._data[key]
            print(f" -> Data ditemukan: {nilai}")
            return nilai
        except KeyError:

            print(f" -> ERROR: Key '{key}' tidak ditemukan di DataStore '{self.nama}'.")
            return None

# Kode output
if __name__ == "__main__":
    store_produk = DataStore("Toko Produk")

    store_produk.tambah_data("Buku Tulis", 15000)
    store_produk.tambah_data("Pensil 2B", 2000)

    print("\nMengambil data yang ADA:")
    harga_buku = store_produk.get_data("Buku Tulis")
    if harga_buku is not None:
        print(f" Harga Buku Tulis adalah: {harga_buku}")

    print("\nMengambil data yang TIDAK ADA:")
    harga_penggaris = store_produk.get_data("Penggaris")
    if harga_penggaris is None:
        print(" Harga Penggaris tidak ditemukan (sesuai ekspektasi).")
# Out:
# DataStore 'Toko Produk' dibuat.
# [Toko Produk] Menambahkan data: 'Buku Tulis' -> 15000
#  -> Data berhasil ditambahkan.
# [Toko Produk] Menambahkan data: 'Pensil 2B' -> 2000
#  -> Data berhasil ditambahkan.
#
# Mengambil data yang ADA:
# [Toko Produk] Mencoba mengambil data dengan key: 'Buku Tulis'
#  -> Data ditemukan: 15000
#  Harga Buku Tulis adalah: 15000
#
# Mengambil data yang TIDAK ADA:
# [Toko Produk] Mencoba mengambil data dengan key: 'Penggaris'
#  -> ERROR: Key 'Penggaris' tidak ditemukan di DataStore 'Toko Produk'.
#  Harga Penggaris tidak ditemukan (sesuai ekspektasi).

# %% [markdown]
# #Praktikum 02: Menangani Beberapa Exception Spesifik

# %%
class KalkulatorAngka:
    def __init__(self):
        print("Kalkulator Angka siap.")

    def bagi(self, angka1, angka2):
        """
        Membagi angka1 dengan angka2.
        Menangani potensi ValueError (jika input bukan angka)
        dan ZeroDivisionError (jika pembagi nol) secara terpisah.
        """
        print(f"\nMencoba membagi '{angka1}' dengan '{angka2}'...")
        try:
            num1 = float(angka1)
            num2 = float(angka2)

            hasil = num1 / num2

            print(f" -> Hasil pembagian: {hasil}")
            return hasil

        except ValueError:
            print(" -> ERROR: Input tidak valid! Pastikan kedua input adalah angka.")
            return None

        except ZeroDivisionError:
            print(" -> ERROR: Tidak bisa melakukan pembagian dengan nol.")
            return None

        except Exception as e:
            print(f" -> ERROR Lainnya: Terjadi kesalahan - {e}")
            return None

# kode untuk output
if __name__ == "__main__":
    calc = KalkulatorAngka()

    print("--- Tes Kalkulator ---")
    hasil1 = calc.bagi(100, 5)
    hasil2 = calc.bagi(20, 0)
    hasil3 = calc.bagi("limapuluh", 10)
    hasil4 = calc.bagi(50, "sepuluh")

    print("\n--- Ringkasan Hasil ---")
    print(f"Hasil 1 (100/5): {hasil1}")
    print(f"Hasil 2 (20/0): {hasil2}")
    print(f"Hasil 3 ('limapuluh'/10): {hasil3}")
    print(f"Hasil 4 (50/'sepuluh'): {hasil4}")
# Out:
# Kalkulator Angka siap.
# --- Tes Kalkulator ---
#
# Mencoba membagi '100' dengan '5'...
#  -> Hasil pembagian: 20.0
#
# Mencoba membagi '20' dengan '0'...
#  -> ERROR: Tidak bisa melakukan pembagian dengan nol.
#
# Mencoba membagi 'limapuluh' dengan '10'...
#  -> ERROR: Input tidak valid! Pastikan kedua input adalah angka.
#
# Mencoba membagi '50' dengan 'sepuluh'...
#  -> ERROR: Input tidak valid! Pastikan kedua input adalah angka.
#
# --- Ringkasan Hasil ---
# Hasil 1 (100/5): 20.0
# Hasil 2 (20/0): None
# Hasil 3 ('limapuluh'/10): None
# Hasil 4 (50/'sepuluh'): None

# %% [markdown]
# #Praktikum 03: Menggunakan else dan finally dalam Metode

# %%
import os

class FileProcessor:
    def __init__(self, nama_file):
        self.nama_file = nama_file
        self._file_handle = None
        print(f"\n-> FileProcessor dibuat untuk file: '{self.nama_file}'")

    def baca_dan_proses(self):
        """Membuka, membaca, dan 'memproses' file, dengan cleanup di finally."""
        print(f"[{self.nama_file}] Mencoba memproses...")
        try:

            print(f"  [{self.nama_file}] Membuka file...")
            self._file_handle = open(self.nama_file, 'r', encoding='utf-8')


            print(f"  [{self.nama_file}] Membaca isi file...")
            isi = self._file_handle.read()
            print(f"  -> File berhasil dibaca.")


            print(f"  [{self.nama_file}] Memproses isi...")
            panjang_isi = len(isi)
            print(f"  -> Panjang isi: {panjang_isi} karakter.")

        except FileNotFoundError:

            print(f"  -> ERROR: File '{self.nama_file}' tidak ditemukan.")
        except UnicodeDecodeError:

            print(f"  -> ERROR: Gagal membaca '{self.nama_file}' sebagai teks (mungkin file biner?).")
        except Exception as e:

            print(f"  -> ERROR Lainnya saat memproses file: {type(e).__name__} - {e}")
        else:

            print(f"  -> PEMROSESAN BERHASIL: Tidak ada error terjadi pada '{self.nama_file}'.")
        finally:

            print(f"  [{self.nama_file}] Blok Finally: Melakukan cleanup...")
            if self._file_handle and not self._file_handle.closed:
                print(f"  Menutup file '{self.nama_file}'...")
                self._file_handle.close()
                print("  -> File berhasil ditutup.")
            else:

                print("  -> File tidak perlu ditutup (belum dibuka atau sudah ditutup).")

        print(f"[{self.nama_file}] Selesai mencoba proses.")
        print("-" * 30)


# Kode output
if __name__ == "__main__":
    NAMA_FILE_SUKSES = "data_penting.txt"
    NAMA_FILE_GAGAL = "file_yang_tidak_ada.log"

    try:
        with open(NAMA_FILE_SUKSES, "w", encoding='utf-8') as f:
            f.write("Ini adalah baris pertama.\n")
            f.write("Baris kedua berisi data penting.\n")
        print(f"File dummy '{NAMA_FILE_SUKSES}' berhasil dibuat.")
    except IOError as e:
        print(f"Gagal membuat file dummy '{NAMA_FILE_SUKSES}': {e}")

    print("\n--- Skenario 1: Proses Sukses ---")
    processor1 = FileProcessor(NAMA_FILE_SUKSES)
    processor1.baca_dan_proses()

    print("\n--- Skenario 2: File Tidak Ditemukan ---")
    processor2 = FileProcessor(NAMA_FILE_GAGAL)
    processor2.baca_dan_proses()

    try:
        if os.path.exists(NAMA_FILE_SUKSES):
            os.remove(NAMA_FILE_SUKSES)
            print(f"\nFile dummy '{NAMA_FILE_SUKSES}' dihapus.")
    except OSError as e:
        print(f"\nGagal menghapus file dummy '{NAMA_FILE_SUKSES}': {e}")
# Out:
# File dummy 'data_penting.txt' berhasil dibuat.
#
# --- Skenario 1: Proses Sukses ---
#
# -> FileProcessor dibuat untuk file: 'data_penting.txt'
# [data_penting.txt] Mencoba memproses...
#   [data_penting.txt] Membuka file...
#   [data_penting.txt] Membaca isi file...
#   -> File berhasil dibaca.
#   [data_penting.txt] Memproses isi...
#   -> Panjang isi: 59 karakter.
#   -> PEMROSESAN BERHASIL: Tidak ada error terjadi pada 'data_penting.txt'.
#   [data_penting.txt] Blok Finally: Melakukan cleanup...
#   Menutup file 'data_penting.txt'...
#   -> File berhasil ditutup.
# [data_penting.txt] Selesai mencoba proses.
# ------------------------------
#
# --- Skenario 2: File Tidak Ditemukan ---
#
# -> FileProcessor dibuat untuk file: 'file_yang_tidak_ada.log'
# [file_yang_tidak_ada.log] Mencoba memproses...
#   [file_yang_tidak_ada.log] Membuka file...
#   -> ERROR: File 'file_yang_tidak_ada.log' tidak ditemukan.
#   [file_yang_tidak_ada.log] Blok Finally: Melakukan cleanup...
#   -> File tidak perlu ditutup (belum dibuka atau sudah ditutup).
# [file_yang_tidak_ada.log] Selesai mencoba proses.
# ------------------------------
#
# File dummy 'data_penting.txt' dihapus.

# %% [markdown]
# #Praktikum 04: Mengakses Objek Exception (as e)

# %%
class KalkulatorAngka:
    def __init__(self):
        print("Kalkulator Angka siap.")

    def bagi(self, angka1, angka2):
        """
        Membagi angka1 dengan angka2.
        Menangkap objek exception untuk menampilkan detail error.
        """
        print(f"\nMencoba membagi '{angka1}' dengan '{angka2}'...")
        try:
            num1 = float(angka1)
            num2 = float(angka2)

            if num2 == 0:
                raise ZeroDivisionError("Pembagi tidak boleh nol secara eksplisit.")

            hasil = num1 / num2
            print(f" -> Hasil pembagian: {hasil}")
            return hasil

        except ValueError as e_val:
            print(f" -> ERROR Konversi: Input tidak valid.")
            print(f"    Detail Error (ValueError): {e_val}")
            return None

        except ZeroDivisionError as e_zero:
            print(f" -> ERROR Pembagian: Tidak dapat membagi dengan nol.")
            print(f"    Detail Error (ZeroDivisionError): {e_zero}")
            return None

        except Exception as e:
            print(f" -> ERROR Lainnya: Terjadi kesalahan tak terduga.")
            print(f"    Detail Error (Lainnya): {type(e).__name__} - {e}")
            return None

# Kode output
if __name__ == "__main__":
    calc = KalkulatorAngka()

    print("--- Tes Kalkulator ---")
    hasil1 = calc.bagi(100, 5)
    hasil2 = calc.bagi(20, 0)
    hasil3 = calc.bagi("limapuluh", 10)
    hasil4 = calc.bagi(10, [])

    print("\n--- Ringkasan Hasil ---")
    print(f"Hasil 1 (100/5): {hasil1}")
    print(f"Hasil 2 (20/0): {hasil2}")
    print(f"Hasil 3 ('limapuluh'/10): {hasil3}")
    print(f"Hasil 4 (10/[]): {hasil4}")
# Out:
# Kalkulator Angka siap.
# --- Tes Kalkulator ---
#
# Mencoba membagi '100' dengan '5'...
#  -> Hasil pembagian: 20.0
#
# Mencoba membagi '20' dengan '0'...
#  -> ERROR Pembagian: Tidak dapat membagi dengan nol.
#     Detail Error (ZeroDivisionError): Pembagi tidak boleh nol secara eksplisit.
#
# Mencoba membagi 'limapuluh' dengan '10'...
#  -> ERROR Konversi: Input tidak valid.
#     Detail Error (ValueError): could not convert string to float: 'limapuluh'
#
# Mencoba membagi '10' dengan '[]'...
#  -> ERROR Lainnya: Terjadi kesalahan tak terduga.
#     Detail Error (Lainnya): TypeError - float() argument must be a string or a real number, not 'list'
#
# --- Ringkasan Hasil ---
# Hasil 1 (100/5): 20.0
# Hasil 2 (20/0): None
# Hasil 3 ('limapuluh'/10): None
# Hasil 4 (10/[]): None

# %% [markdown]
# #Praktikum 05: Membangkitkan Exception (raise) dalam Metode

# %%
class PengelolaAkun:
    def __init__(self, nomor_akun, saldo_awal=0):
        print(f"\n[Sistem] Mencoba membuat akun {nomor_akun}...")

        if saldo_awal < 0:
            raise ValueError(f"Saldo awal tidak boleh negatif! Input: {saldo_awal}")

        self.nomor_akun = nomor_akun
        self._saldo = float(saldo_awal)
        print(f" -> Akun {self.nomor_akun} berhasil dibuat. Saldo: Rp {self._saldo:,.2f}")

    def get_saldo(self):
        return self._saldo

    def tarik_tunai(self, jumlah):
        print(f"\n[{self.nomor_akun}] Memproses penarikan: Rp {jumlah:,.2f}")

        if jumlah <= 0:
            raise ValueError(f"Jumlah penarikan harus lebih besar dari nol! Input: {jumlah}")

        if jumlah > self._saldo:
            raise RuntimeError(f"Saldo tidak cukup! Saldo saat ini: Rp {self._saldo:,.2f}")

        self._saldo -= jumlah
        print(f" -> Penarikan berhasil.")
        print(f" -> Sisa saldo sekarang: Rp {self._saldo:,.2f}")
        return True


# Kode output
if __name__ == "__main__":
    print("=== UJI COBA PRAKTIKUM 05: MEMBANGKITKAN EXCEPTION (RAISE) ===")

    try:
        akun_bad = PengelolaAkun("ACC-999", -50000)
    except ValueError as e:
        print(f" -> [EXCEPT TERTANGKAP] Gagal membuat akun karena: {e}")

    try:
        akun_good = PengelolaAkun("ACC-001", 100000)

        akun_good.tarik_tunai(40000)

        akun_good.tarik_tunai(-10000)

    except ValueError as e:
        print(f" -> [EXCEPT TERTANGKAP] Validasi penarikan gagal: {e}")
    except RuntimeError as e:
        print(f" -> [EXCEPT TERTANGKAP] Masalah saldo: {e}")

    try:
        print(f"\nSaldo akhir akun ACC-001 saat ini: Rp {akun_good.get_saldo():,.2f}")
        akun_good.tarik_tunai(70000)

    except ValueError as e:
        print(f" -> [EXCEPT TERTANGKAP] {e}")
    except RuntimeError as e:
        print(f" -> [EXCEPT TERTANGKAP] Proses dihentikan: {e}")
# Out:
# === UJI COBA PRAKTIKUM 05: MEMBANGKITKAN EXCEPTION (RAISE) ===
#
# [Sistem] Mencoba membuat akun ACC-999...
#  -> [EXCEPT TERTANGKAP] Gagal membuat akun karena: Saldo awal tidak boleh negatif! Input: -50000
#
# [Sistem] Mencoba membuat akun ACC-001...
#  -> Akun ACC-001 berhasil dibuat. Saldo: Rp 100,000.00
#
# [ACC-001] Memproses penarikan: Rp 40,000.00
#  -> Penarikan berhasil.
#  -> Sisa saldo sekarang: Rp 60,000.00
#
# [ACC-001] Memproses penarikan: Rp -10,000.00
#  -> [EXCEPT TERTANGKAP] Validasi penarikan gagal: Jumlah penarikan harus lebih besar dari nol! Input: -10000
#
# Saldo akhir akun ACC-001 saat ini: Rp 60,000.00
#
# [ACC-001] Memproses penarikan: Rp 70,000.00
#  -> [EXCEPT TERTANGKAP] Proses dihentikan: Saldo tidak cukup! Saldo saat ini: Rp 60,000.00

# %% [markdown]
# #Praktikum 06: Kombinasi Menangkap dan Membangkitkan Exception

# %%
class KonfigurasiError(Exception):
    """Exception khusus untuk menandakan error terkait konfigurasi aplikasi."""
    def __init__(self, message, penyebab_asli=None):
        super().__init__(message)
        self.penyebab_asli = penyebab_asli

    def __str__(self):
        if self.penyebab_asli:
            return f"{super().__str__()} (Disebabkan oleh: {type(self.penyebab_asli).__name__})"
        return super().__str__()


class PengelolaSetting:
    def __init__(self, file_config):
        self._config = {}
        self.file_config = file_config

        try:
            self._load_config()
            print(f"-> PengelolaSetting berhasil dibuat untuk '{self.file_config}'.")
        except KonfigurasiError as e:
            print(f"-> GAGAL membuat PengelolaSetting: {e}")
            self._config = {}
            print("   -> Menggunakan konfigurasi default/kosong.")

    def _load_config(self):
        """Metode internal untuk load config. Bisa raise KonfigurasiError."""
        print(f"\n[{self.file_config}] Mencoba load konfigurasi...")
        try:
            print(f"   Membuka file '{self.file_config}'...")
            if self.file_config != 'config.txt':
                raise FileNotFoundError(f"File '{self.file_config}' tidak ada.")

            print(f"   Membaca dan validasi isi '{self.file_config}'...")

            data_raw = {"host": "192.168.1.1", "port": "xyz"}

            if 'port' not in data_raw:
                raise KeyError("port")
            port_str = data_raw['port']

            port_int = int(port_str)

            self._config = {"host": data_raw['host'], "port": port_int}
            print("   -> Konfigurasi berhasil dimuat ke memori.")

        except FileNotFoundError as e_fnf:
            raise KonfigurasiError("Gagal memuat setting karena berkas fisik eksternal hilang.", penyebab_asli=e_fnf)

        except KeyError as e_key:
            raise KonfigurasiError(f"Struktur data konfigurasi tidak lengkap. Key hilang: {e_key}", penyebab_asli=e_key)

        except ValueError as e_val:
            raise KonfigurasiError("Nilai konfigurasi tidak valid (Format data salah).", penyebab_asli=e_val)


# Kode output
if __name__ == "__main__":
    print("=== UJI COBA PRAKTIKUM 06: KOMBINASI EXCEPTION ===")

    print("\n--- Skenario 1: File Salah ---")
    setting_salah_file = PengelolaSetting("wrong_config.json")

    print("\n--- Skenario 2: File Benar, Isi Invalid ---")
    setting_salah_isi = PengelolaSetting("config.txt")
# Out:
# === UJI COBA PRAKTIKUM 06: KOMBINASI EXCEPTION ===
#
# --- Skenario 1: File Salah ---
#
# [wrong_config.json] Mencoba load konfigurasi...
#    Membuka file 'wrong_config.json'...
# -> GAGAL membuat PengelolaSetting: Gagal memuat setting karena berkas fisik eksternal hilang. (Disebabkan oleh: FileNotFoundError)
#    -> Menggunakan konfigurasi default/kosong.
#
# --- Skenario 2: File Benar, Isi Invalid ---
#
# [config.txt] Mencoba load konfigurasi...
#    Membuka file 'config.txt'...
#    Membaca dan validasi isi 'config.txt'...
# -> GAGAL membuat PengelolaSetting: Nilai konfigurasi tidak valid (Format data salah). (Disebabkan oleh: ValueError)
#    -> Menggunakan konfigurasi default/kosong.

# %% [markdown]
# #Buat Program dan Kelas diagram

# %%
class InventarisBarang:
    def __init__(self):
        self._items = {}
        print("Sistem Inventaris Barang Berhasil Diinisialisasi.")

    def tambah_barang(self, kode, jumlah):
        print(f"\n[TAMBAH BARANG] Mencoba menambah kode '{kode}' dengan jumlah: {jumlah}")
        try:

            jumlah_int = int(jumlah)
            if jumlah_int <= 0:
                raise ValueError("Jumlah harus berupa integer positif.")

            if kode in self._items:
                raise KeyError(f"Error: Kode barang '{kode}' sudah ada.")

            self._items[kode] = jumlah_int
            print(f" -> BERHASIL: Barang '{kode}' ditambahkan ke inventaris dengan stok: {jumlah_int}")

        except ValueError as e:
            print(f" -> ERROR (ValueError) di tambah_barang: {e}")

    def ambil_barang(self, kode, jumlah):
        print(f"\n[AMBIL BARANG] Mencoba mengambil barang '{kode}' sebanyak: {jumlah}")
        try:
            jumlah_int = int(jumlah)
            if jumlah_int <= 0:
                raise ValueError("Jumlah pengambilan harus berupa integer positif.")

            if kode not in self._items:
                raise KeyError(f"Error: Kode barang '{kode}' tidak ditemukan.")

            stok_sekarang = self._items[kode]
            if jumlah_int > stok_sekarang:
                raise ValueError(f"Error: Stok barang '{kode}' tidak mencukupi (tersedia: {stok_sekarang}, diminta: {jumlah_int}).")

            self._items[kode] -= jumlah_int
            print(f" -> BERHASIL: Mengambil {jumlah_int} item dari '{kode}'. Sisa stok: {self._items[kode]}")

        except ValueError as e:
            print(f" -> ERROR (ValueError) di ambil_barang: {e}")
        except KeyError as e:
            print(f" -> ERROR (KeyError) di ambil_barang: {e}")

    def cek_stok(self, kode):
        print(f"\n[CEK STOK] Memeriksa barang dengan kode '{kode}'")
        try:
            stok = self._items[kode]
        except KeyError:
            print(f" -> ERROR: Barang dengan kode '{kode}' tidak ditemukan dalam inventaris.")
        else:
            print(f" -> INFO: Jumlah stok untuk kode '{kode}' adalah: {stok}")
        finally:
            print(f" -> [SISTEM] Pengecekan stok untuk kode '{kode}' telah selesai dilakukan.")


if __name__ == "__main__":
    inventaris = InventarisBarang()

    print("\n" + "="*20 + " PENGUJIAN: TAMBAH BARANG " + "="*20)
    inventaris.tambah_barang("BRG001", 50)
    inventaris.tambah_barang("BRG002", 20)

    inventaris.tambah_barang("BRG003", -10)
    inventaris.tambah_barang("BRG004", "sepuluh")

    try:
        inventaris.tambah_barang("BRG001", 30)
    except KeyError as e:
        print(f" -> [MAIN EXCEPT] Tertangkap di kode utama: {e}")


    print("\n" + "="*20 + " PENGUJIAN: AMBIL BARANG " + "="*20)
    inventaris.ambil_barang("BRG001", 15)

    inventaris.ambil_barang("BRG099", 5)

    inventaris.ambil_barang("BRG001", -5)

    inventaris.ambil_barang("BRG002", 40)


    print("\n" + "="*20 + " PENGUJIAN: CEK STOK (try...except...else...finally) " + "="*20)
    inventaris.cek_stok("BRG001")

    inventaris.cek_stok("BRG099")

    print("\n==================== PENGUJIAN SELESAI ====================")
# Out:
# Sistem Inventaris Barang Berhasil Diinisialisasi.
#
# ==================== PENGUJIAN: TAMBAH BARANG ====================
#
# [TAMBAH BARANG] Mencoba menambah kode 'BRG001' dengan jumlah: 50
#  -> BERHASIL: Barang 'BRG001' ditambahkan ke inventaris dengan stok: 50
#
# [TAMBAH BARANG] Mencoba menambah kode 'BRG002' dengan jumlah: 20
#  -> BERHASIL: Barang 'BRG002' ditambahkan ke inventaris dengan stok: 20
#
# [TAMBAH BARANG] Mencoba menambah kode 'BRG003' dengan jumlah: -10
#  -> ERROR (ValueError) di tambah_barang: Jumlah harus berupa integer positif.
#
# [TAMBAH BARANG] Mencoba menambah kode 'BRG004' dengan jumlah: sepuluh
#  -> ERROR (ValueError) di tambah_barang: invalid literal for int() with base 10: 'sepuluh'
#
# [TAMBAH BARANG] Mencoba menambah kode 'BRG001' dengan jumlah: 30
#  -> [MAIN EXCEPT] Tertangkap di kode utama: "Error: Kode barang 'BRG001' sudah ada."
#
# ==================== PENGUJIAN: AMBIL BARANG ====================
#
# [AMBIL BARANG] Mencoba mengambil barang 'BRG001' sebanyak: 15
#  -> BERHASIL: Mengambil 15 item dari 'BRG001'. Sisa stok: 35
#
# [AMBIL BARANG] Mencoba mengambil barang 'BRG099' sebanyak: 5
#  -> ERROR (KeyError) di ambil_barang: "Error: Kode barang 'BRG099' tidak ditemukan."
#
# [AMBIL BARANG] Mencoba mengambil barang 'BRG001' sebanyak: -5
#  -> ERROR (ValueError) di ambil_barang: Jumlah pengambilan harus berupa integer positif.
#
# [AMBIL BARANG] Mencoba mengambil barang 'BRG002' sebanyak: 40
#  -> ERROR (ValueError) di ambil_barang: Error: Stok barang 'BRG002' tidak mencukupi (tersedia: 20, diminta: 40).
#
# ==================== PENGUJIAN: CEK STOK (try...except...else...finally) ====================
#
# [CEK STOK] Memeriksa barang dengan kode 'BRG001'
#  -> INFO: Jumlah stok untuk kode 'BRG001' adalah: 35
#  -> [SISTEM] Pengecekan stok untuk kode 'BRG001' telah selesai dilakukan.
#
# [CEK STOK] Memeriksa barang dengan kode 'BRG099'
#  -> ERROR: Barang dengan kode 'BRG099' tidak ditemukan dalam inventaris.
#  -> [SISTEM] Pengecekan stok untuk kode 'BRG099' telah selesai dilakukan.
#
# ==================== PENGUJIAN SELESAI ====================
